# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

# %% [markdown]
# Place to get into the correct place for accessing the pickle file

# %%
cd  Desktop\V9_all_scans_dict_87_88_89_90_91_92_93_94_MD_81_to_1939.pickle
# Out:
# C:\Users\cae2\Desktop\V9_all_scans_dict_87_88_89_90_91_92_93_94_MD_81_to_1939.pickle

# %%
data_dict = pd.read_pickle("V9_all_scans_dict_87_88_89_90_91_92_93_94_MD_81_to_1939.pickle")
print(f"Imported files with keys {data_dict.keys()}")
# Out:
# Imported files with keys dict_keys([87, 88, 89, 90, 91, 92, 93, 94])

# %%
df = data_dict[88]

# %%
ds = xr.Dataset.from_dataframe(df, sparse=True)
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (scan_time: 504, wavelength: 233)
# Coordinates:
#   * scan_time            (scan_time) float64 81.31 106.4 ... 1.939e+03 1.939e+03
#   * wavelength           (wavelength) float64 800.5 803.2 ... 1.741e+03
# Data variables:
#     pt_time              (scan_time, wavelength) float64 <COO: nnz=63831, fill_value=nan>
#     sirr                 (scan_time, wavelength) float64 <COO: nnz=63831, fill_value=nan>
#     imode                (scan_time, wavelength) float64 <COO: nnz=63831, fill_value=nan>
#     detector             (scan_time, wavelength) object <COO: nnz=63831, fill_value=nan>
#     channel              (scan_time, wavelength) object <COO: nnz=63831, fill_value=nan>
#     solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=63831, fill_value=nan>
#     activity_name        (scan_time, wavelength) object <COO: nnz=63831, fill_value=nan>

# %%
# create the flat array
detectors = ds.detector.to_numpy().ravel()
# iterate through the array and only keep string data
detectors = [detector for detector in detectors if type(detector) is str]
# convert to a set to get unique values
list(set(detectors))
# Out:
# ['IR']

# %%
# create the flat array
channels = ds.channel.to_numpy().ravel()
# iterate through the array and only keep string data
channels = [channel for channel in channels if type(channel) is str]
# convert to a set to get unique values
list(set(channels))
# Out:
# ['B']

# %%
def unique_string_from_sparse_dataarray(da):
    xs = da.to_numpy().ravel()
    xs = [x for x in xs if type(x) is str]
    xs = list(set(xs))
    if len(xs) == 1:
        return xs[0]
    else:
        return xs

# %%
unique_string_from_sparse_dataarray(ds.channel)
# Out:
# 'B'

# %%
dataset_dict = {
    key: xr.Dataset.from_dataframe(df, sparse=True) for key, df in data_dict.items()
}  # exactly is just data_dict

# %%
keys = list(
    dataset_dict.keys()
)  # list because error, and maybe this disconnects data from dictionary
for key in keys:
    ds = dataset_dict.pop(key)
    new_key = unique_string_from_sparse_dataarray(
        ds.channel
    ), unique_string_from_sparse_dataarray(ds.detector)
    dataset_dict[new_key] = ds
dataset_dict
# Out:
# {('B',
#   'ESR'): <xarray.Dataset>
#  Dimensions:              (scan_time: 691, wavelength: 902)
#  Coordinates:
#    * scan_time            (scan_time) float64 82.47 82.66 ... 1.939e+03 1.939e+03
#    * wavelength           (wavelength) float64 263.9 264.0 ... 2.399e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=51612, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=51612, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=51612, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=51612, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=51612, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=51612, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=51612, fill_value=nan>,
#  ('B',
#   'IR'): <xarray.Dataset>
#  Dimensions:              (scan_time: 504, wavelength: 233)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.31 106.4 ... 1.939e+03 1.939e+03
#    * wavelength           (wavelength) float64 800.5 803.2 ... 1.741e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=63831, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=63831, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=63831, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=63831, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=63831, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=63831, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=63831, fill_value=nan>,
#  ('B',
#   'VIS'): <xarray.Dataset>
#  Dimensions:              (scan_time: 949, wavelength: 856)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.31 106.4 ... 1.938e+03 1.939e+03
#    * wavelength           (wavelength) float64 299.8 300.0 ... 1.187e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=198440, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=198440, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=198440, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=198440, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=198440, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=198440, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=198440, fill_value=nan>,
#  ('B',
#   'UV'): <xarray.Dataset>
#  Dimensions:              (scan_time: 587, wavelength: 1082)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.12 81.14 ... 1.936e+03 1.936e+03
#    * wavelength           (wavelength) float64 200.0 200.1 200.1 ... 312.6 312.8
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=193358, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=193358, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=193358, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=193358, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=193358, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=193358, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=193358, fill_value=nan>,
#  ('C',
#   'ESR'): <xarray.Dataset>
#  Dimensions:              (scan_time: 150, wavelength: 939)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.57 81.76 ... 1.939e+03 1.939e+03
#    * wavelength           (wavelength) float64 241.9 242.1 ... 2.399e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=8986, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=8986, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=8986, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=8986, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=8986, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=8986, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=8986, fill_value=nan>,
#  ('C',
#   'IR'): <xarray.Dataset>
#  Dimensions:              (scan_time: 55, wavelength: 227)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.38 291.4 ... 1.939e+03 1.939e+03
#    * wavelength           (wavelength) float64 803.2 805.9 ... 1.703e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=5706, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=5706, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=5706, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=5706, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=5706, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=5706, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=5706, fill_value=nan>,
#  ('C',
#   'VIS'): <xarray.Dataset>
#  Dimensions:              (scan_time: 107, wavelength: 846)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.38 291.4 ... 1.939e+03 1.939e+03
#    * wavelength           (wavelength) float64 299.8 300.0 ... 1.146e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=15768, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=15768, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=15768, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=15768, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=15768, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=15768, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=15768, fill_value=nan>,
#  ('C',
#   'UV'): <xarray.Dataset>
#  Dimensions:              (scan_time: 65, wavelength: 1083)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.18 81.2 ... 1.937e+03 1.937e+03
#    * wavelength           (wavelength) float64 200.0 200.1 200.1 ... 312.8 313.0
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=12394, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=12394, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=12394, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=12394, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=12394, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=12394, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=12394, fill_value=nan>}

# %%
dataset_dict.keys()
# Out:
# dict_keys([('B', 'ESR'), ('B', 'IR'), ('B', 'VIS'), ('B', 'UV'), ('C', 'ESR'), ('C', 'IR'), ('C', 'VIS'), ('C', 'UV')])

# %%
da = ds.sirr[:, 400]  # get the time series of the ESR at the 400th wavelength
da = da.as_numpy()  # convert to numpy array so not sparse now
da = da.dropna(dim="scan_time")  # drop elements with no value
da.interp(scan_time=750)  # interpolate the value to the scan time 750

# note this all could have been a single line just appending the methods at the end
# Out:
# <xarray.DataArray 'sirr' ()>
# array(0.05620793)
# Coordinates:
#     wavelength  float64 223.2
#     scan_time   int32 750

# %%
ds_vis_a = dataset_dict["B", "VIS"]
ds_esr_a = dataset_dict["B", "ESR"]

# %%
good_wl = [wl in ds_esr_a.wavelength.values for wl in ds_vis_a.wavelength.values]
fig, ax = plt.subplots(1)
ax.plot(ds_vis_a.wavelength.values, good_wl, ".")
fig.set_size_inches([4, 2])
ax.set_xlabel("wavelength (nm)")
ax.set_ylabel("wavelength exists in\nESR data")
# Out:
# Text(0, 0.5, 'wavelength exists in\nESR data')

# %%
ds_combined = xr.combine_by_coords(
    [ds_vis_a.as_numpy(), ds_esr_a.as_numpy().rename({"sirr": "sirr_esr"})],
    data_vars=["sirr", "sirr_esr"],
    join="outer",
)
ds_combined.as_numpy()
# Out:
# <xarray.Dataset>
# Dimensions:              (scan_time: 1640, wavelength: 1147)
# Coordinates:
#   * scan_time            (scan_time) float64 81.31 82.47 ... 1.939e+03 1.939e+03
#   * wavelength           (wavelength) float64 263.9 264.0 ... 2.399e+03
# Data variables:
#     pt_time              (scan_time, wavelength) float64 nan nan nan ... nan nan
#     sirr                 (scan_time, wavelength) float64 nan nan nan ... nan nan
#     imode                (scan_time, wavelength) float64 nan nan nan ... nan nan
#     detector             (scan_time, wavelength) object nan nan nan ... nan nan
#     channel              (scan_time, wavelength) object nan nan nan ... nan nan
#     solar_exposure_days  (scan_time, wavelength) float64 nan nan nan ... nan nan
#     activity_name        (scan_time, wavelength) object nan nan nan ... nan nan
#     sirr_esr             (scan_time, wavelength) float64 nan nan nan ... nan nan

# %%
fig,ax = plt.subplots(1,2)
x,y = np.where(ds_vis_a.sirr.to_numpy()>0)
ax[0].plot(ds_vis_a.wavelength.to_numpy()[y],ds_vis_a.scan_time.to_numpy()[x],'.',markersize=.25)
x,y = np.where(ds_combined.sirr.to_numpy()>0)
ax[1].plot(ds_combined.wavelength.to_numpy()[y],ds_combined.scan_time.to_numpy()[x],'.',markersize=.25)
fig.set_size_inches([8,5])

# %%
ds_combined["sirr_esr_interp"] = ds_combined.sirr_esr.interpolate_na(
    dim="scan_time", method="linear"
)

# %%
da_ratio = (ds_combined.sirr / ds_combined.sirr_esr_interp)

# %%
scan_time = ds_combined.scan_time.to_numpy()

# %%
da_ratio_interp = da_ratio.interpolate_na(
    dim="scan_time", method="linear"
)

# %%
fig, ax=plt.subplots(1)
da_ratio_interp.sel(wavelength = slice(395, 1020)).plot(x = "scan_time", robust = True, vmin = .995, vmax = 1.001)
ax.set_xlabel("Date")
ax.set_ylabel("Wavelength (nm)")
ax.set_title("TSIS SIM Channel B VIS Diode Degredation")
# Out:
# Text(0.5, 1.0, 'TSIS SIM Channel B VIS Diode Degredation')

# %%
plt.gci()

# %%
da_ratio_interp.sel(wavelength = slice(500, 900)).plot(x = "scan_time", robust = True)

# %%
da_ratio_interp.sel(wavelength = slice(395, 500)).plot(x = "scan_time", robust = True)

# %%
da_ratio_interp.sel(wavelength = slice(900, 1020)).plot(x = "scan_time", robust = True)
