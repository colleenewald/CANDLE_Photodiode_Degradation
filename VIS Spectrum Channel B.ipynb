# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

# %%
cd TSIS_V10_pickles/
# Out:
# C:\Users\cae2\Downloads\TSIS_V10_pickles

# %%
data_dict = pd.read_pickle(
    "V10_prod_all_scans_dict_83_84_85_86_87_88_89_90_91_92_93_94_MD_81_to_2000.pickle"
)
print(f"Imported files with keys {data_dict.keys()}")
# Out:
# Imported files with keys dict_keys([83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94])

# %%
data_dict
# Out:
# {83:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.442223   241.949     1.204282e+15  0.065921   83.0      ESR       A
#              242.054     1.204282e+15  0.068930   83.0      ESR       A
#              242.160     1.204282e+15  0.068484   83.0      ESR       A
#              242.267     1.204282e+15  0.070194   83.0      ESR       A
#              242.373     1.204282e+15  0.071357   83.0      ESR       A
#  ...                              ...       ...    ...      ...     ...
#  1999.965870 221.409     1.370043e+15  0.037898   83.0      ESR       A
#              221.482     1.370044e+15  0.036366   83.0      ESR       A
#              221.554     1.370044e+15  0.034461   83.0      ESR       A
#              221.627     1.370044e+15  0.034583   83.0      ESR       A
#              221.700     1.370044e+15  0.033361   83.0      ESR       A
#
#                          solar_exposure_days      activity_name
#  scan_time   wavelength
#  81.442223   241.949                0.057442    SolarESRMode1_A
#              242.054                0.057442    SolarESRMode1_A
#              242.160                0.057442    SolarESRMode1_A
#              242.267                0.057442    SolarESRMode1_A
#              242.373                0.057442    SolarESRMode1_A
#  ...                                     ...                ...
#  1999.965870 221.409              205.248061  EsrResearchScan_A
#              221.482              205.248061  EsrResearchScan_A
#              221.554              205.248061  EsrResearchScan_A
#              221.627              205.248061  EsrResearchScan_A
#              221.700              205.248061  EsrResearchScan_A
#
#  [303043 rows x 7 columns],
#  84:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.249237   803.186     1.204266e+15  1.116432   84.0       IR       A
#              805.903     1.204266e+15  1.104058   84.0       IR       A
#              808.636     1.204266e+15  1.095371   84.0       IR       A
#              811.391     1.204266e+15  1.088642   84.0       IR       A
#              814.156     1.204266e+15  1.081320   84.0       IR       A
#  ...                              ...       ...    ...      ...     ...
#  1999.191296 1657.633    1.369977e+15  0.220486   84.0       IR       A
#              1665.292    1.369977e+15  0.217401   84.0       IR       A
#              1672.936    1.369977e+15  0.214836   84.0       IR       A
#              1680.559    1.369977e+15  0.223433   84.0       IR       A
#              1688.159    1.369977e+15  0.279680   84.0       IR       A
#
#                          solar_exposure_days      activity_name
#  scan_time   wavelength
#  81.249237   803.186                0.025382  SolarPDFullScan_A
#              805.903                0.025382  SolarPDFullScan_A
#              808.636                0.025382  SolarPDFullScan_A
#              811.391                0.025382  SolarPDFullScan_A
#              814.156                0.025382  SolarPDFullScan_A
#  ...                                     ...                ...
#  1999.191296 1657.633             205.202655  SolarPDFullScan_A
#              1665.292             205.202655  SolarPDFullScan_A
#              1672.936             205.202655  SolarPDFullScan_A
#              1680.559             205.202655  SolarPDFullScan_A
#              1688.159             205.202655  SolarPDFullScan_A
#
#  [605617 rows x 7 columns],
#  85:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.249237   300.029     1.204265e+15  0.436617   85.0      VIS       A
#              300.242     1.204265e+15  0.422361   85.0      VIS       A
#              300.454     1.204265e+15  0.423052   85.0      VIS       A
#              300.668     1.204265e+15  0.433353   85.0      VIS       A
#              300.881     1.204265e+15  0.437074   85.0      VIS       A
#  ...                              ...       ...    ...      ...     ...
#  1999.191296 1105.893    1.369977e+15  0.573322   85.0      VIS       A
#              1109.881    1.369977e+15  0.569570   85.0      VIS       A
#              1113.887    1.369977e+15  0.566677   85.0      VIS       A
#              1117.919    1.369977e+15  0.561090   85.0      VIS       A
#              1121.942    1.369977e+15  0.545311   85.0      VIS       A
#
#                          solar_exposure_days      activity_name
#  scan_time   wavelength
#  81.249237   300.029                0.025382  SolarPDFullScan_A
#              300.242                0.025382  SolarPDFullScan_A
#              300.454                0.025382  SolarPDFullScan_A
#              300.668                0.025382  SolarPDFullScan_A
#              300.881                0.025382  SolarPDFullScan_A
#  ...                                     ...                ...
#  1999.191296 1105.893             205.202655  SolarPDFullScan_A
#              1109.881             205.202655  SolarPDFullScan_A
#              1113.887             205.202655  SolarPDFullScan_A
#              1117.919             205.202655  SolarPDFullScan_A
#              1121.942             205.202655  SolarPDFullScan_A
#
#  [2238476 rows x 7 columns],
#  86:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.056667   200.015     1.204248e+15  0.006915   86.0       UV       A
#              200.060     1.204248e+15  0.006938   86.0       UV       A
#              200.104     1.204248e+15  0.006976   86.0       UV       A
#              200.149     1.204248e+15  0.007082   86.0       UV       A
#              200.194     1.204248e+15  0.007184   86.0       UV       A
#  ...                              ...       ...    ...      ...     ...
#  1999.077673 311.698     1.369966e+15  0.691580   86.0       UV       A
#              311.870     1.369966e+15  0.683422   86.0       UV       A
#              312.054     1.369966e+15  0.671280   86.0       UV       A
#              312.231     1.369966e+15  0.662333   86.0       UV       A
#              312.412     1.369966e+15  0.657733   86.0       UV       A
#
#                          solar_exposure_days           activity_name
#  scan_time   wavelength
#  81.056667   200.015                0.015069  SolarPDUVScan Part 1_A
#              200.060                0.015069  SolarPDUVScan Part 1_A
#              200.104                0.015069  SolarPDUVScan Part 1_A
#              200.149                0.015069  SolarPDUVScan Part 1_A
#              200.194                0.015069  SolarPDUVScan Part 1_A
#  ...                                     ...                     ...
#  1999.077673 311.698              205.192342  SolarPDUVScan Part 2_A
#              311.870              205.192342  SolarPDUVScan Part 2_A
#              312.054              205.192342  SolarPDUVScan Part 2_A
#              312.231              205.192342  SolarPDUVScan Part 2_A
#              312.412              205.192342  SolarPDUVScan Part 2_A
#
#  [2823304 rows x 7 columns],
#  87:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.506552   241.949     1.204287e+15  0.066154   87.0      ESR       B
#              242.054     1.204287e+15  0.068890   87.0      ESR       B
#              242.160     1.204287e+15  0.068559   87.0      ESR       B
#              242.267     1.204288e+15  0.070195   87.0      ESR       B
#              242.373     1.204288e+15  0.071299   87.0      ESR       B
#  ...                              ...       ...    ...      ...     ...
#  1998.354287 319.344     1.369905e+15  0.795139   87.0      ESR       B
#              319.539     1.369905e+15  0.813479   87.0      ESR       B
#              319.733     1.369905e+15  0.833545   87.0      ESR       B
#              319.930     1.369905e+15  0.849880   87.0      ESR       B
#              320.125     1.369905e+15  0.855762   87.0      ESR       B
#
#                          solar_exposure_days     activity_name
#  scan_time   wavelength
#  81.506552   241.949                0.057395   SolarESRMode1_B
#              242.054                0.057395   SolarESRMode1_B
#              242.160                0.057395   SolarESRMode1_B
#              242.267                0.057395   SolarESRMode1_B
#              242.373                0.057395   SolarESRMode1_B
#  ...                                     ...               ...
#  1998.354287 319.344               24.196153  SolarESRMode4i_B
#              319.539               24.196153  SolarESRMode4i_B
#              319.733               24.196153  SolarESRMode4i_B
#              319.930               24.196153  SolarESRMode4i_B
#              320.125               24.196153  SolarESRMode4i_B
#
#  [66889 rows x 7 columns],
#  88:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.313612   800.478     1.204272e+15  1.123482   88.0       IR       B
#              803.186     1.204272e+15  1.114152   88.0       IR       B
#              805.903     1.204272e+15  1.103354   88.0       IR       B
#              808.636     1.204272e+15  1.093651   88.0       IR       B
#              811.391     1.204272e+15  1.087287   88.0       IR       B
#  ...                              ...       ...    ...      ...     ...
#  1995.385919 1649.938    1.369648e+15  0.223658   88.0       IR       B
#              1657.633    1.369648e+15  0.220925   88.0       IR       B
#              1665.292    1.369648e+15  0.218012   88.0       IR       B
#              1672.936    1.369648e+15  0.214743   88.0       IR       B
#              1680.559    1.369648e+15  0.217024   88.0       IR       B
#
#                          solar_exposure_days      activity_name
#  scan_time   wavelength
#  81.313612   800.478                0.025335  SolarPDFullScan_B
#              803.186                0.025335  SolarPDFullScan_B
#              805.903                0.025335  SolarPDFullScan_B
#              808.636                0.025335  SolarPDFullScan_B
#              811.391                0.025335  SolarPDFullScan_B
#  ...                                     ...                ...
#  1995.385919 1649.938              24.154671  SolarPDFullScan_B
#              1657.633              24.154671  SolarPDFullScan_B
#              1665.292              24.154671  SolarPDFullScan_B
#              1672.936              24.154671  SolarPDFullScan_B
#              1680.559              24.154671  SolarPDFullScan_B
#
#  [65988 rows x 7 columns],
#  89:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.313612   300.029     1.204270e+15  0.437059   89.0      VIS       B
#              300.242     1.204270e+15  0.422494   89.0      VIS       B
#              300.454     1.204270e+15  0.422789   89.0      VIS       B
#              300.668     1.204270e+15  0.433000   89.0      VIS       B
#              300.881     1.204270e+15  0.436896   89.0      VIS       B
#  ...                              ...       ...    ...      ...     ...
#  1998.352678 319.930     1.369903e+15  0.754894   89.0      VIS       B
#              320.125     1.369903e+15  0.760698   89.0      VIS       B
#              320.323     1.369903e+15  0.762466   89.0      VIS       B
#              320.520     1.369903e+15  0.761337   89.0      VIS       B
#              320.720     1.369903e+15  0.758225   89.0      VIS       B
#
#                          solar_exposure_days      activity_name
#  scan_time   wavelength
#  81.313612   300.029                0.025335  SolarPDFullScan_B
#              300.242                0.025335  SolarPDFullScan_B
#              300.454                0.025335  SolarPDFullScan_B
#              300.668                0.025335  SolarPDFullScan_B
#              300.881                0.025335  SolarPDFullScan_B
#  ...                                     ...                ...
#  1998.352678 319.930               24.183653     SolarPDMode4_B
#              320.125               24.183653     SolarPDMode4_B
#              320.323               24.183653     SolarPDMode4_B
#              320.520               24.183653     SolarPDMode4_B
#              320.720               24.183653     SolarPDMode4_B
#
#  [210645 rows x 7 columns],
#  90:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.120602   200.015     1.204254e+15  0.006915   90.0       UV       B
#              200.060     1.204254e+15  0.006937   90.0       UV       B
#              200.104     1.204254e+15  0.006975   90.0       UV       B
#              200.149     1.204254e+15  0.007081   90.0       UV       B
#              200.194     1.204254e+15  0.007184   90.0       UV       B
#  ...                              ...       ...    ...      ...     ...
#  1997.384174 295.694     1.369819e+15  0.543407   90.0       UV       B
#              295.896     1.369819e+15  0.539826   90.0       UV       B
#              296.098     1.369819e+15  0.535823   90.0       UV       B
#              296.301     1.369819e+15  0.519889   90.0       UV       B
#              296.502     1.369819e+15  0.500822   90.0       UV       B
#
#                          solar_exposure_days           activity_name
#  scan_time   wavelength
#  81.120602   200.015                0.015023  SolarPDUVScan Part 1_B
#              200.060                0.015023  SolarPDUVScan Part 1_B
#              200.104                0.015023  SolarPDUVScan Part 1_B
#              200.149                0.015023  SolarPDUVScan Part 1_B
#              200.194                0.015023  SolarPDUVScan Part 1_B
#  ...                                     ...                     ...
#  1997.384174 295.694               24.169486          SolarPDMode4_B
#              295.896               24.169486          SolarPDMode4_B
#              296.098               24.169486          SolarPDMode4_B
#              296.301               24.169486          SolarPDMode4_B
#              296.502               24.169486          SolarPDMode4_B
#
#  [200779 rows x 7 columns],
#  91:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.570812   241.949     1.204293e+15  0.066090   91.0      ESR       C
#              242.054     1.204293e+15  0.068868   91.0      ESR       C
#              242.160     1.204293e+15  0.068486   91.0      ESR       C
#              242.267     1.204293e+15  0.070204   91.0      ESR       C
#              242.373     1.204293e+15  0.071327   91.0      ESR       C
#  ...                              ...       ...    ...      ...     ...
#  1938.974669 1828.096    1.364774e+15  0.154813   91.0      ESR       C
#              1835.222    1.364774e+15  0.152859   91.0      ESR       C
#              1842.333    1.364774e+15  0.151059   91.0      ESR       C
#              1849.418    1.364774e+15  0.149038   91.0      ESR       C
#              1853.338    1.364774e+15  0.147684   91.0      ESR       C
#
#                          solar_exposure_days      activity_name
#  scan_time   wavelength
#  81.570812   241.949                0.057396    SolarESRMode1_C
#              242.054                0.057396    SolarESRMode1_C
#              242.160                0.057396    SolarESRMode1_C
#              242.267                0.057396    SolarESRMode1_C
#              242.373                0.057396    SolarESRMode1_C
#  ...                                     ...                ...
#  1938.974669 1828.096               2.772121  SolarESRIRScan1_C
#              1835.222               2.772121  SolarESRIRScan1_C
#              1842.333               2.772121  SolarESRIRScan1_C
#              1849.418               2.772121  SolarESRIRScan1_C
#              1853.338               2.772121  SolarESRIRScan1_C
#
#  [8984 rows x 7 columns],
#  92:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.378010   803.186     1.204277e+15  1.116844   92.0       IR       C
#              805.903     1.204277e+15  1.105813   92.0       IR       C
#              808.636     1.204277e+15  1.096713   92.0       IR       C
#              811.391     1.204277e+15  1.089953   92.0       IR       C
#              814.156     1.204277e+15  1.082666   92.0       IR       C
#  ...                              ...       ...    ...      ...     ...
#  1938.781126 1672.936    1.364756e+15  0.214970   92.0       IR       C
#              1680.559    1.364756e+15  0.217585   92.0       IR       C
#              1688.159    1.364756e+15  0.236035   92.0       IR       C
#              1695.731    1.364756e+15  0.408031   92.0       IR       C
#              1703.277    1.364756e+15 -0.598605   92.0       IR       C
#
#                          solar_exposure_days      activity_name
#  scan_time   wavelength
#  81.378010   803.186                0.025335  SolarPDFullScan_C
#              805.903                0.025335  SolarPDFullScan_C
#              808.636                0.025335  SolarPDFullScan_C
#              811.391                0.025335  SolarPDFullScan_C
#              814.156                0.025335  SolarPDFullScan_C
#  ...                                     ...                ...
#  1938.781126 1672.936               2.743706    SolarPDMode12_C
#              1680.559               2.743706    SolarPDMode12_C
#              1688.159               2.743706    SolarPDMode12_C
#              1695.731               2.743706    SolarPDMode12_C
#              1703.277               2.743706    SolarPDMode12_C
#
#  [5706 rows x 7 columns],
#  93:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.378010   300.029     1.204276e+15  0.436410   93.0      VIS       C
#              300.242     1.204276e+15  0.422275   93.0      VIS       C
#              300.454     1.204276e+15  0.423260   93.0      VIS       C
#              300.668     1.204276e+15  0.433528   93.0      VIS       C
#              300.881     1.204276e+15  0.437069   93.0      VIS       C
#  ...                              ...       ...    ...      ...     ...
#  1938.781126 1125.949    1.364756e+15  0.545640   93.0      VIS       C
#              1129.999    1.364756e+15  0.556588   93.0      VIS       C
#              1134.038    1.364756e+15  0.586770   93.0      VIS       C
#              1138.101    1.364756e+15  0.646719   93.0      VIS       C
#              1142.155    1.364756e+15  0.764072   93.0      VIS       C
#
#                          solar_exposure_days      activity_name
#  scan_time   wavelength
#  81.378010   300.029                0.025335  SolarPDFullScan_C
#              300.242                0.025335  SolarPDFullScan_C
#              300.454                0.025335  SolarPDFullScan_C
#              300.668                0.025335  SolarPDFullScan_C
#              300.881                0.025335  SolarPDFullScan_C
#  ...                                     ...                ...
#  1938.781126 1125.949               2.743706    SolarPDMode12_C
#              1129.999               2.743706    SolarPDMode12_C
#              1134.038               2.743706    SolarPDMode12_C
#              1138.101               2.743706    SolarPDMode12_C
#              1142.155               2.743706    SolarPDMode12_C
#
#  [15769 rows x 7 columns],
#  94:                              pt_time      sirr  imode detector channel  \
#  scan_time   wavelength
#  81.184908   200.015     1.204259e+15  0.006916   94.0       UV       C
#              200.060     1.204259e+15  0.006937   94.0       UV       C
#              200.104     1.204259e+15  0.006977   94.0       UV       C
#              200.149     1.204259e+15  0.007084   94.0       UV       C
#              200.194     1.204259e+15  0.007185   94.0       UV       C
#  ...                              ...       ...    ...      ...     ...
#  1937.167349 310.150     1.364616e+15  0.586434   94.0       UV       C
#              310.389     1.364616e+15  0.626052   94.0       UV       C
#              310.629     1.364616e+15  0.670233   94.0       UV       C
#              310.870     1.364616e+15  0.704466   94.0       UV       C
#              311.111     1.364616e+15  0.725744   94.0       UV       C
#
#                          solar_exposure_days           activity_name
#  scan_time   wavelength
#  81.184908   200.015                0.015023  SolarPDUVScan Part 1_C
#              200.060                0.015023  SolarPDUVScan Part 1_C
#              200.104                0.015023  SolarPDUVScan Part 1_C
#              200.149                0.015023  SolarPDUVScan Part 1_C
#              200.194                0.015023  SolarPDUVScan Part 1_C
#  ...                                     ...                     ...
#  1937.167349 310.150                2.624041          SolarPDMode5_C
#              310.389                2.624041          SolarPDMode5_C
#              310.629                2.624041          SolarPDMode5_C
#              310.870                2.624041          SolarPDMode5_C
#              311.111                2.624041          SolarPDMode5_C
#
#  [12394 rows x 7 columns]}

# %%
df = data_dict[83]
df
# Out:
#                              pt_time      sirr  imode detector channel  \
# scan_time   wavelength
# 81.442223   241.949     1.204282e+15  0.065921   83.0      ESR       A
#             242.054     1.204282e+15  0.068930   83.0      ESR       A
#             242.160     1.204282e+15  0.068484   83.0      ESR       A
#             242.267     1.204282e+15  0.070194   83.0      ESR       A
#             242.373     1.204282e+15  0.071357   83.0      ESR       A
# ...                              ...       ...    ...      ...     ...
# 1999.965870 221.409     1.370043e+15  0.037898   83.0      ESR       A
#             221.482     1.370044e+15  0.036366   83.0      ESR       A
#             221.554     1.370044e+15  0.034461   83.0      ESR       A
#             221.627     1.370044e+15  0.034583   83.0      ESR       A
#             221.700     1.370044e+15  0.033361   83.0      ESR       A
#
#                         solar_exposure_days      activity_name
# scan_time   wavelength
# 81.442223   241.949                0.057442    SolarESRMode1_A
#             242.054                0.057442    SolarESRMode1_A
#             242.160                0.057442    SolarESRMode1_A
#             242.267                0.057442    SolarESRMode1_A
#             242.373                0.057442    SolarESRMode1_A
# ...                                     ...                ...
# 1999.965870 221.409              205.248061  EsrResearchScan_A
#             221.482              205.248061  EsrResearchScan_A
#             221.554              205.248061  EsrResearchScan_A
#             221.627              205.248061  EsrResearchScan_A
#             221.700              205.248061  EsrResearchScan_A
#
# [303043 rows x 7 columns]

# %%
ds = xr.Dataset.from_dataframe(df, sparse=True)
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (scan_time: 7347, wavelength: 1876)
# Coordinates:
#   * scan_time            (scan_time) float64 81.44 81.64 81.83 ... 2e+03 2e+03
#   * wavelength           (wavelength) float64 210.0 210.1 ... 2.399e+03
# Data variables:
#     pt_time              (scan_time, wavelength) float64 <COO: nnz=303043, fill_value=nan>
#     sirr                 (scan_time, wavelength) float64 <COO: nnz=303043, fill_value=nan>
#     imode                (scan_time, wavelength) float64 <COO: nnz=303043, fill_value=nan>
#     detector             (scan_time, wavelength) object <COO: nnz=303043, fill_value=nan>
#     channel              (scan_time, wavelength) object <COO: nnz=303043, fill_value=nan>
#     solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=303043, fill_value=nan>
#     activity_name        (scan_time, wavelength) object <COO: nnz=303043, fill_value=nan>

# %%
ds.sirr.plot()

# %%
ds.sirr.to_numpy()
# Out:
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ..., 0.05953894, 0.05904326,
#         0.05875331],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]])

# %%
# create the flat array
detectors = ds.detector.to_numpy().ravel()
# iterate through the array and only keep string data
detectors = [detector for detector in detectors if type(detector) is str]
# convert to a set to get unique values
list(set(detectors))
# Out:
# ['ESR']

# %%
# create the flat array
channels = ds.channel.to_numpy().ravel()
# iterate through the array and only keep string data
channels = [channel for channel in channels if type(channel) is str]
# convert to a set to get unique values
list(set(channels))
# Out:
# ['A']

# %%
def unique_string_from_sparse_dataarray(da):
    xs = da.to_numpy().ravel()
    xs = [x for x in xs if type(x) is str]
    xs = list(set(xs))
    if len(xs) == 1:
        return xs[0]
    else:
        return xs

# %%
unique_string_from_sparse_dataarray(ds.channel)
# Out:
# 'A'

# %%
dataset_dict = {
    key: xr.Dataset.from_dataframe(df, sparse=True) for key, df in data_dict.items()
}  # exactly is just data_dict

# %%
keys = list(
    dataset_dict.keys()
)  # list because error, and maybe this disconnects data from dictionary
for key in keys:
    ds = dataset_dict.pop(key)
    new_key = unique_string_from_sparse_dataarray(
        ds.channel
    ), unique_string_from_sparse_dataarray(ds.detector)
    dataset_dict[new_key] = ds
dataset_dict
# Out:
# {('A',
#   'ESR'): <xarray.Dataset>
#  Dimensions:              (scan_time: 7347, wavelength: 1876)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.44 81.64 81.83 ... 2e+03 2e+03
#    * wavelength           (wavelength) float64 210.0 210.1 ... 2.399e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=303043, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=303043, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=303043, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=303043, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=303043, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=303043, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=303043, fill_value=nan>,
#  ('A',
#   'IR'): <xarray.Dataset>
#  Dimensions:              (scan_time: 3038, wavelength: 233)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.25 90.19 ... 1.999e+03 1.999e+03
#    * wavelength           (wavelength) float64 800.5 803.2 ... 1.741e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=605617, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=605617, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=605617, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=605617, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=605617, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=605617, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=605617, fill_value=nan>,
#  ('A',
#   'VIS'): <xarray.Dataset>
#  Dimensions:              (scan_time: 3947, wavelength: 846)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.25 90.19 ... 1.999e+03 1.999e+03
#    * wavelength           (wavelength) float64 299.8 300.0 ... 1.146e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=2238476, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=2238476, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=2238476, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=2238476, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=2238476, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=2238476, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=2238476, fill_value=nan>,
#  ('A',
#   'UV'): <xarray.Dataset>
#  Dimensions:              (scan_time: 5692, wavelength: 1082)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.06 81.07 ... 1.999e+03 1.999e+03
#    * wavelength           (wavelength) float64 200.0 200.1 200.1 ... 312.6 312.8
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=2823304, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=2823304, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=2823304, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=2823304, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=2823304, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=2823304, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=2823304, fill_value=nan>,
#  ('B',
#   'ESR'): <xarray.Dataset>
#  Dimensions:              (scan_time: 1172, wavelength: 940)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.51 81.7 ... 1.997e+03 1.998e+03
#    * wavelength           (wavelength) float64 241.9 242.1 ... 2.399e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=66889, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=66889, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=66889, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=66889, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=66889, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=66889, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=66889, fill_value=nan>,
#  ('B',
#   'IR'): <xarray.Dataset>
#  Dimensions:              (scan_time: 540, wavelength: 233)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.31 106.4 ... 1.991e+03 1.995e+03
#    * wavelength           (wavelength) float64 800.5 803.2 ... 1.741e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=65988, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=65988, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=65988, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=65988, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=65988, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=65988, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=65988, fill_value=nan>,
#  ('B',
#   'VIS'): <xarray.Dataset>
#  Dimensions:              (scan_time: 1050, wavelength: 856)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.31 106.4 ... 1.997e+03 1.998e+03
#    * wavelength           (wavelength) float64 299.8 300.0 ... 1.187e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=210645, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=210645, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=210645, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=210645, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=210645, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=210645, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=210645, fill_value=nan>,
#  ('B',
#   'UV'): <xarray.Dataset>
#  Dimensions:              (scan_time: 625, wavelength: 1082)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.12 81.14 ... 1.996e+03 1.997e+03
#    * wavelength           (wavelength) float64 200.0 200.1 200.1 ... 312.6 312.8
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=200779, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=200779, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=200779, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=200779, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=200779, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=200779, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=200779, fill_value=nan>,
#  ('C',
#   'ESR'): <xarray.Dataset>
#  Dimensions:              (scan_time: 150, wavelength: 939)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.57 81.76 ... 1.939e+03 1.939e+03
#    * wavelength           (wavelength) float64 241.9 242.1 ... 2.399e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=8984, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=8984, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=8984, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=8984, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=8984, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=8984, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=8984, fill_value=nan>,
#  ('C',
#   'IR'): <xarray.Dataset>
#  Dimensions:              (scan_time: 55, wavelength: 227)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.38 291.4 ... 1.939e+03 1.939e+03
#    * wavelength           (wavelength) float64 803.2 805.9 ... 1.703e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=5706, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=5706, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=5706, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=5706, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=5706, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=5706, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=5706, fill_value=nan>,
#  ('C',
#   'VIS'): <xarray.Dataset>
#  Dimensions:              (scan_time: 107, wavelength: 845)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.38 291.4 ... 1.939e+03 1.939e+03
#    * wavelength           (wavelength) float64 299.8 300.0 ... 1.142e+03
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=15769, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=15769, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=15769, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=15769, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=15769, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=15769, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=15769, fill_value=nan>,
#  ('C',
#   'UV'): <xarray.Dataset>
#  Dimensions:              (scan_time: 65, wavelength: 1083)
#  Coordinates:
#    * scan_time            (scan_time) float64 81.18 81.2 ... 1.937e+03 1.937e+03
#    * wavelength           (wavelength) float64 200.0 200.1 200.1 ... 312.8 313.0
#  Data variables:
#      pt_time              (scan_time, wavelength) float64 <COO: nnz=12394, fill_value=nan>
#      sirr                 (scan_time, wavelength) float64 <COO: nnz=12394, fill_value=nan>
#      imode                (scan_time, wavelength) float64 <COO: nnz=12394, fill_value=nan>
#      detector             (scan_time, wavelength) object <COO: nnz=12394, fill_value=nan>
#      channel              (scan_time, wavelength) object <COO: nnz=12394, fill_value=nan>
#      solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=12394, fill_value=nan>
#      activity_name        (scan_time, wavelength) object <COO: nnz=12394, fill_value=nan>}

# %%
dataset_dict[("B", "IR")]
# Out:
# <xarray.Dataset>
# Dimensions:              (scan_time: 540, wavelength: 233)
# Coordinates:
#   * scan_time            (scan_time) float64 81.31 106.4 ... 1.991e+03 1.995e+03
#   * wavelength           (wavelength) float64 800.5 803.2 ... 1.741e+03
# Data variables:
#     pt_time              (scan_time, wavelength) float64 <COO: nnz=65988, fill_value=nan>
#     sirr                 (scan_time, wavelength) float64 <COO: nnz=65988, fill_value=nan>
#     imode                (scan_time, wavelength) float64 <COO: nnz=65988, fill_value=nan>
#     detector             (scan_time, wavelength) object <COO: nnz=65988, fill_value=nan>
#     channel              (scan_time, wavelength) object <COO: nnz=65988, fill_value=nan>
#     solar_exposure_days  (scan_time, wavelength) float64 <COO: nnz=65988, fill_value=nan>
#     activity_name        (scan_time, wavelength) object <COO: nnz=65988, fill_value=nan>

# %%
dataset_dict.keys()
# Out:
# dict_keys([('A', 'ESR'), ('A', 'IR'), ('A', 'VIS'), ('A', 'UV'), ('B', 'ESR'), ('B', 'IR'), ('B', 'VIS'), ('B', 'UV'), ('C', 'ESR'), ('C', 'IR'), ('C', 'VIS'), ('C', 'UV')])

# %%
len(dataset_dict)
# Out:
# 12

# %%
ds = dataset_dict["C", "ESR"]

# %%
ds.sirr[:, 500].as_numpy().dropna(dim="scan_time")
# Out:
# <xarray.DataArray 'sirr' (scan_time: 10)>
# array([1.77222216, 1.77221754, 1.77190196, 1.7723653 , 1.7721555 ,
#        1.77265467, 1.77199934, 1.77268521, 1.77320847, 1.77408486])
# Coordinates:
#   * scan_time   (scan_time) float64 83.11 293.1 473.3 ... 1.756e+03 1.938e+03
#     wavelength  float64 600.1

# %%
fig, ax = plt.subplots(1)
for n in range(len(ds.wavelength)):
    try:
        da = ds.sirr[:, n].as_numpy().dropna(dim="scan_time")
        da = da / da[0]  # normalize to one for first element
        da.plot(ax=ax)
    except:
        pass  # this ignores all errors. generally a poor way to do it
fig.set_size_inches([5, 3])
ax.set_title("trend for all wavelengths of ESR")
# Out:
# Text(0.5, 1.0, 'trend for all wavelengths of ESR')

# %%
da = ds.sirr[:, 400]  # get the time series of the ESR at the 400th wavelength
da = da.as_numpy()  # convert to numpy array so not sparse now
da = da.dropna(dim="scan_time")  # drop elements with no value
da.interp(scan_time=750)  # interpolate the value to the scan time 750

# note this all could have been a single line just appending the methods at the end
# Out:
# <xarray.DataArray 'sirr' ()>
# array(1.99858267)
# Coordinates:
#     wavelength  float64 494.5
#     scan_time   int32 750

# %%
ds_vis_b = dataset_dict["B", "VIS"]
ds_esr_b = dataset_dict["B", "ESR"]

# %%
ds_vis_b.wavelength
# Out:
# <xarray.DataArray 'wavelength' (wavelength: 856)>
# array([ 299.817,  300.029,  300.242, ..., 1178.902, 1183.006, 1187.112])
# Coordinates:
#   * wavelength  (wavelength) float64 299.8 300.0 300.2 ... 1.183e+03 1.187e+03

# %%
ds_esr_b.wavelength
# Out:
# <xarray.DataArray 'wavelength' (wavelength: 940)>
# array([ 241.949,  242.054,  242.16 , ..., 2388.265, 2393.784, 2399.011])
# Coordinates:
#   * wavelength  (wavelength) float64 241.9 242.1 242.2 ... 2.394e+03 2.399e+03

# %%
good_wl = [wl in ds_esr_b.wavelength.values for wl in ds_vis_b.wavelength.values]
fig, ax = plt.subplots(1)
ax.plot(ds_vis.wavelength.values, good_wl, ".")
fig.set_size_inches([4, 2])
ax.set_xlabel("wavelength (nm)")
ax.set_ylabel("wavelength exists in\nESR data")
# Out:
# Text(0, 0.5, 'wavelength exists in\nESR data')

# %%
ds_combined = xr.combine_by_coords(
    [ds_vis_b.as_numpy(), ds_esr_b.as_numpy().rename({"sirr": "sirr_esr"})],
    data_vars=["sirr", "sirr_esr"],
    join="outer",
)
ds_combined.as_numpy()
# Out:
# <xarray.Dataset>
# Dimensions:              (scan_time: 2222, wavelength: 1183)
# Coordinates:
#   * scan_time            (scan_time) float64 81.31 81.51 ... 1.998e+03 1.998e+03
#   * wavelength           (wavelength) float64 241.9 242.1 ... 2.399e+03
# Data variables:
#     pt_time              (scan_time, wavelength) float64 nan nan nan ... nan nan
#     sirr                 (scan_time, wavelength) float64 nan nan nan ... nan nan
#     imode                (scan_time, wavelength) float64 nan nan nan ... nan nan
#     detector             (scan_time, wavelength) object nan nan nan ... nan nan
#     channel              (scan_time, wavelength) object nan nan nan ... nan nan
#     solar_exposure_days  (scan_time, wavelength) float64 nan nan nan ... nan nan
#     activity_name        (scan_time, wavelength) object nan nan nan ... nan nan
#     sirr_esr             (scan_time, wavelength) float64 nan nan nan ... nan nan

# %%
fig, ax = plt.subplots(1)
ds_combined.sirr.plot(ax=ax)
ds_combined.sirr_esr.plot(ax=ax)
fig.set_size_inches([6, 4])

# %%
fig,ax = plt.subplots(1,2)
x,y = np.where(ds_vis_b.sirr.to_numpy()>0)
ax[0].plot(ds_vis_b.wavelength.to_numpy()[y],ds_vis_b.scan_time.to_numpy()[x],'.',markersize=.25)
x,y = np.where(ds_combined.sirr.to_numpy()>0)
ax[1].plot(ds_combined.wavelength.to_numpy()[y],ds_combined.scan_time.to_numpy()[x],'.',markersize=.25)
fig.set_size_inches([8,5])

# %%
ds_combined["sirr_esr_interp"] = ds_combined.sirr_esr.interpolate_na(
    dim="scan_time", method="linear"
)

# %%
(ds_combined.sirr / ds_combined.sirr_esr_interp).plot()

# %%
(ds_combined.sirr_esr_interp / ds_combined.sirr).plot(robust = True)

# %%
da_ratio = (ds_combined.sirr / ds_combined.sirr_esr_interp)

# %%
scan_time = ds_combined.scan_time.to_numpy()
sample_times = np.linspace(scan_time[0], scan_time[-1], 5)

# %%
da_ratio_interp = da_ratio.interpolate_na(
    dim="scan_time", method="linear"
)
fig, ax=plt.subplots(1)
da_ratio_interp.sel(scan_time = 82, method = "nearest").sel(wavelength = slice(380, 1020)).plot(ax=ax)
ax.get_lines()[0].set_label(ax.get_title())
da_ratio_interp.sel(scan_time = 447, method = "nearest").sel(wavelength = slice(380, 1020)).plot(ax=ax)
ax.get_lines()[1].set_label(ax.get_title())
da_ratio_interp.sel(scan_time = 812, method = "nearest").sel(wavelength = slice(380, 1020)).plot(ax=ax)
ax.get_lines()[2].set_label(ax.get_title())
da_ratio_interp.sel(scan_time = 1177, method = "nearest").sel(wavelength = slice(380, 1020)).plot(ax=ax)
ax.get_lines()[3].set_label(ax.get_title())
da_ratio_interp.sel(scan_time = 1543, method = "nearest").sel(wavelength = slice(380, 1020)).plot(ax=ax)
ax.get_lines()[4].set_label(ax.get_title())
da_ratio_interp.sel(scan_time = 1900, method = "nearest").sel(wavelength = slice(380, 1020)).plot(ax=ax)
ax.get_lines()[5].set_label(ax.get_title())

ax.legend(frameon= False)
ax.set_ylabel("Ratioed Solar Irradiance")
ax.set_xlabel("Wavelength")
ax.set_title("VIS Spectrum Channel B")
# Out:
# Text(0.5, 1.0, 'VIS Spectrum Channel B')
